# %%
# %run ./utils

# %%
# Read source tables from catalog
employee_df = spark.table("default.employee_q_1")
department_df = spark.table("default.department_q_1")
country_df = spark.table("default.country_q_1")

# %%
# Check data
display(employee_df)
display(department_df)
display(country_df)

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.source_to_bronze;

# %%
# Write to DBFS bronze layer as CSV
write_csv_to_dbfs(employee_df, "/Volumes/workspace/default/source_to_bronze/employee.csv")
write_csv_to_dbfs(department_df, "/Volumes/workspace/default/source_to_bronze/department_df.csv")
write_csv_to_dbfs(country_df, "/Volumes/workspace/default/source_to_bronze/country_df.csv")

# %%
# Verify output
display(dbutils.fs.ls("/Volumes/workspace/default/source_to_bronze"))
